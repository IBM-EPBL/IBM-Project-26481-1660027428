# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %% [markdown]
# # 2. Loading the dataset

# %%
data = pd.read_csv("C:\senthilraja\Churn_Modelling.csv")

# %% [markdown]
# # 3. Univariate Analysis

# %%
data = pd.read_csv("C:\senthilraja\Churn_Modelling.csv")

# %%
sns.distplot(data['NumOfProducts'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='NumOfProducts', ylabel='Density'>

# %%
sns.histplot(data['Balance'])
# Out:
# <AxesSubplot:xlabel='Balance', ylabel='Count'>

# %%
sns.boxplot(data['Age'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# # 3. Bivariate Analysis

# %%
sns.lineplot(data['EstimatedSalary'], data['Geography'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='EstimatedSalary', ylabel='Geography'>

# %%
sns.barplot(data['Tenure'], data['Exited'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Tenure', ylabel='Exited'>

# %%
sns.scatterplot(data['IsActiveMember'], data['Balance'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='IsActiveMember', ylabel='Balance'>

# %%
sns.scatterplot(data['Tenure'], data['Geography'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Tenure', ylabel='Geography'>

# %% [markdown]
# # 3. Multivariate Analysis

# %%
sns.scatterplot(data['CustomerId'], data['Exited'], hue = data['Age'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CustomerId', ylabel='Exited'>

# %%
sns.scatterplot(data['Gender'], data['EstimatedSalary'], hue = data['Gender'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='EstimatedSalary'>

# %%
sns.scatterplot(data['Gender'], data['CreditScore'], hue = data['Gender'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='CreditScore'>

# %%
sns.pairplot(data)

# %% [markdown]
# # 4. Descriptive Statistics

# %% [markdown]
# ## Central Tendency

# %%
data.mean()

# %%
data.median()

# %%
data.mode()

# %%
data.describe()

# %% [markdown]
# ##  Dispersion of Data

# %%
sns.boxplot(data['HasCrCard'])

# %% [markdown]
# ### Interquartile Range

# %%
q = data.quantile([0.75, 0.25])

# %%
q

# %%
iqr = q.iloc[0] - q.iloc[1]

# %%
iqr

# %%
u = q.iloc[0] + 1.5*iqr

# %%
u

# %%
l = q.iloc[1] - 1.5*iqr

# %%
l

# %% [markdown]
# ## Variance

# %%
data.var()

# %% [markdown]
# ## Standard Deviation

# %%
data.std()

# %%
data.notnull()

# %% [markdown]
# # 5.Handle the missing values:

# %%
 data.fillna(0)

# %% [markdown]
# ## 6. Outliers and handling them

# %%
sns.boxplot(data['NumOfProducts'])

# %%
data['Tenure'].mean()

# %%
data['Age'] = np.where(data['Age'] > 50, 39, data['Age'])

# %%
sns.boxplot(data['Age'])

# %%
sns.boxplot(data['CustomerId')

# %%
data['Age'].mean()

# %%
data['CreditScore'] = np.where(data['CreditScore'] < 400, 650, data['CreditScore'])

# %%
sns.boxplot(data['CreditScore'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CreditScore'>

# %% [markdown]
# # 7. Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['Surname'] = le.fit_transform(data['Surname'])
data['Geography'] = le.fit_transform(data['Geography'])
data['Gender'] = le.fit_transform(data['Gender'])
data.head()
# Out:
#    RowNumber  CustomerId  Surname  CreditScore  Geography  Gender  Age  \
# 0          1    15634602     1115          619          0       0   42
# 1          2    15647311     1177          608          2       0   41
# 2          3    15619304     2040          502          0       0   42
# 3          4    15701354      289          699          0       0   39
# 4          5    15737888     1822          850          2       0   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# # 8. Splitting the data

# %%
x = data.iloc[:, 0:4]

# %%
x
# Out:
#       RowNumber  CustomerId  Surname  CreditScore
# 0             1    15634602     1115          619
# 1             2    15647311     1177          608
# 2             3    15619304     2040          502
# 3             4    15701354      289          699
# 4             5    15737888     1822          850
# ...         ...         ...      ...          ...
# 9995       9996    15606229     1999          771
# 9996       9997    15569892     1336          516
# 9997       9998    15584532     1570          709
# 9998       9999    15682355     2345          772
# 9999      10000    15628319     2751          792
#
# [10000 rows x 4 columns]

# %%
y = data['Tenure']

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 9995    1
# 9996    1
# 9997    0
# 9998    1
# 9999    1
# Name: HasCrCard, Length: 10000, dtype: int64

# %% [markdown]
# # 9. Scaling the independant variables

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
sc = StandardScaler()
x_scaled = sc.fit_transform(x)

# %%
x_scaled
# Out:
# array([[-1.73187761, -0.78321342, -0.46418322, -0.33452426],
#        [-1.7315312 , -0.60653412, -0.3909112 , -0.44928208],
#        [-1.73118479, -0.99588476,  0.62898807, -1.55513017],
#        ...,
#        [ 1.73118479, -1.47928179,  0.07353887,  0.60440336],
#        [ 1.7315312 , -0.11935577,  0.98943914,  1.26165269],
#        [ 1.73187761, -0.87055909,  1.4692527 ,  1.47030328]])

# %% [markdown]
# # 10. Splitting into training and testing set

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size = 0.3, random_state = 0)

# %%
x_train.shape
# Out:
# (7000, 4)

# %%
x_train
# Out:
# array([[ 0.92889885, -0.79703192, -1.47580983, -0.10500862],
#        [ 1.39655257,  0.71431365, -1.58808148, -1.14826153],
#        [-0.4532777 ,  0.96344969, -0.24082173, -0.63706761],
#        ...,
#        [-0.60119484, -1.62052514, -0.36136603,  0.9069467 ],
#        [ 1.67853045, -0.37403866,  0.72589622, -0.63706761],
#        [-0.78548505, -1.36411841,  1.3829808 , -0.29279415]])

# %%
x_test.shape
# Out:
# (3000, 4)

# %%
x_test
# Out:
# array([[ 1.52229946, -1.04525042,  1.39834429, -0.5640399 ],
#        [-1.42080128, -0.50381294, -0.78208925, -1.33604706],
#        [-0.90118604, -0.7932923 ,  0.41271742,  0.57310577],
#        ...,
#        [ 1.49216178, -0.14646448,  0.6868966 ,  0.35402266],
#        [ 1.1758893 , -1.29228727, -1.38481071,  0.42705036],
#        [ 0.08088677, -1.38538833,  1.11707427,  0.833919  ]])

# %%
y_train.shape
# Out:
# (7000,)

# %%
y_train
# Out:
# 7681    1
# 9031    1
# 3691    0
# 202     0
# 5625    1
#        ..
# 9225    1
# 4859    1
# 3264    1
# 9845    1
# 2732    1
# Name: HasCrCard, Length: 7000, dtype: int64

# %%
y_test.shape
# Out:
# (3000,)

# %%
y_test
# Out:
# 9394    1
# 898     1
# 2398    1
# 5906    0
# 2343    1
#        ..
# 4004    0
# 7375    1
# 9307    1
# 8394    1
# 5233    1
# Name: HasCrCard, Length: 3000, dtype: int64
